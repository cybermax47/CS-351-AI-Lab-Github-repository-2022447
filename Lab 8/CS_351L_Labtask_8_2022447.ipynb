# %% [markdown]
# <a href="https://colab.research.google.com/github/cybermax47/CS-351-AI-Lab-Github-repository-2022447/blob/main/CS_351L_Labtask_8_2022447.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Neural Network Tasks with Iris and Wine Datasets**
#
# ---
#
# #### **Overview**
# This project demonstrates building, training, and evaluating neural networks on two well-known datasets: **Iris** and **Wine**. The tasks involve modifying the architecture of the neural network and analyzing its performance. The project showcases concepts like data preprocessing, training visualization, and performance evaluation through metrics like confusion matrices and training history.
#
# ---
#
# #### **Tasks Overview**
#
# ##### **Task 1: Iris Dataset - Modify the Neural Network**
# 1. **Objective**:
#    To evaluate the effect of modifying a simple neural network by adding an additional hidden layer.
#
# 2. **Steps**:
#    - **Data Preprocessing**: The Iris dataset features are standardized, and target labels are one-hot encoded.
#    - **Original Model**: A single-hidden-layer neural network is built with:
#      - 8 neurons in the hidden layer.
#      - ReLU activation for the hidden layer.
#      - Softmax activation for the output layer (3 output units for 3 classes).
#    - **Modified Model**: An additional hidden layer with 16 neurons is added to the architecture.
#    - **Training and Evaluation**:
#      - Both models are trained for 50 epochs with a validation split of 20%.
#      - Training and validation loss/accuracy are compared.
#      - Confusion matrices are generated for the test dataset predictions.
#
# 3. **Deliverables**:
#    - Training and validation loss/accuracy plots.
#    - Confusion matrices for the original and modified models.
#    - Comparative analysis of test accuracy.
#
# ---

# %%
# Task 1: Iris Dataset - Modify the Neural Network

# Import necessary libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Function to preprocess dataset (standardization and one-hot encoding)
def preprocess_data(X, y):
    X = StandardScaler().fit_transform(X)
    y_encoded = OneHotEncoder(sparse_output=False).fit_transform(y.reshape(-1, 1))
    return X, y_encoded

# Function to build and compile a model
def build_model(input_shape, hidden_layers, output_units):
    model = Sequential()
    model.add(Dense(hidden_layers[0], activation='relu', input_shape=(input_shape,)))
    for units in hidden_layers[1:]:
        model.add(Dense(units, activation='relu'))
    model.add(Dense(output_units, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Function to visualize training results
def plot_training_results(history, title):
    plt.figure(figsize=(14, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f'{title} - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title(f'{title} - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.tight_layout()
    plt.show()

# Function to generate and plot confusion matrix
def plot_confusion_matrix(model, X_test, y_test, labels, dataset_name):
    y_pred = np.argmax(model.predict(X_test), axis=1)
    y_true = np.argmax(y_test, axis=1)
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels).plot(
        cmap=plt.cm.Blues, ax=plt.gca()
    )
    plt.title(f'Confusion Matrix - {dataset_name}')
    plt.show()

# Load and preprocess Iris dataset
from sklearn.datasets import load_iris
iris = load_iris()
X_iris, y_iris = iris.data, iris.target
X_iris, y_iris = preprocess_data(X_iris, y_iris)

X_train_iris, X_test_iris, y_train_iris, y_test_iris = train_test_split(
    X_iris, y_iris, test_size=0.2, random_state=42
)

# Build and train the original model
original_model = build_model(input_shape=X_train_iris.shape[1], hidden_layers=[8], output_units=3)
history_original = original_model.fit(
    X_train_iris, y_train_iris, validation_split=0.2, epochs=50, batch_size=16, verbose=1
)

# Build and train the modified model
modified_model = build_model(input_shape=X_train_iris.shape[1], hidden_layers=[8, 16], output_units=3)
history_modified = modified_model.fit(
    X_train_iris, y_train_iris, validation_split=0.2, epochs=50, batch_size=16, verbose=1
)

# Visualization for Task 1
plot_training_results(history_original, "Original Model (Iris Dataset)")
plot_training_results(history_modified, "Modified Model (Iris Dataset)")

# Confusion Matrices for Task 1
plot_confusion_matrix(
    original_model, X_test_iris, y_test_iris, labels=iris.target_names, dataset_name="Iris Dataset (Original Model)"
)
plot_confusion_matrix(
    modified_model, X_test_iris, y_test_iris, labels=iris.target_names, dataset_name="Iris Dataset (Modified Model)"
)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.1955 - loss: 1.2581 - val_accuracy: 0.1250 - val_loss: 1.2330
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2293 - loss: 1.2014 - val_accuracy: 0.1667 - val_loss: 1.2120
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2482 - loss: 1.2228 - val_accuracy: 0.2083 - val_loss: 1.1901
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2231 - loss: 1.1773 - val_accuracy: 0.2083 - val_loss: 1.1699
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2409 - loss: 1.1806 - val_accuracy: 0.2083 - val_loss: 1.1504
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2357 - loss: 1.1723 - val_accuracy: 0.2083 - val_loss: 1.1306
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2766 - loss: 1.1210 - val_accuracy: 0.2500 - val_loss: 1.1112
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3021 - loss: 1.0895 - val_accuracy: 0.2500 - val_loss: 1.0920
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3210 - loss: 1.0706 - val_accuracy: 0.3333 - val_loss: 1.0722
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3848 - loss: 1.0624 - val_accuracy: 0.3333 - val_loss: 1.0531
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4400 - loss: 1.0553 - val_accuracy: 0.3750 - val_loss: 1.0346
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5565 - loss: 1.0326 - val_accuracy: 0.3750 - val_loss: 1.0169
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5622 - loss: 1.0187 - val_accuracy: 0.4167 - val_loss: 0.9983
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5769 - loss: 1.0090 - val_accuracy: 0.4583 - val_loss: 0.9798
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5868 - loss: 0.9894 - val_accuracy: 0.5000 - val_loss: 0.9619
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5411 - loss: 0.9774 - val_accuracy: 0.6250 - val_loss: 0.9440
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6979 - loss: 0.9560 - val_accuracy: 0.7083 - val_loss: 0.9264
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7420 - loss: 0.9381 - val_accuracy: 0.8333 - val_loss: 0.9077
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8000 - loss: 0.9347 - val_accuracy: 0.9167 - val_loss: 0.8896
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8807 - loss: 0.9123 - val_accuracy: 0.9167 - val_loss: 0.8709
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8501 - loss: 0.8962 - val_accuracy: 0.9583 - val_loss: 0.8512
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8969 - loss: 0.8650 - val_accuracy: 0.9583 - val_loss: 0.8315
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9086 - loss: 0.8493 - val_accuracy: 0.9583 - val_loss: 0.8112
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8879 - loss: 0.8414 - val_accuracy: 0.9583 - val_loss: 0.7924
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8741 - loss: 0.8380 - val_accuracy: 0.9583 - val_loss: 0.7738
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9086 - loss: 0.8018 - val_accuracy: 0.9583 - val_loss: 0.7545
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8830 - loss: 0.7803 - val_accuracy: 0.9583 - val_loss: 0.7358
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9198 - loss: 0.7648 - val_accuracy: 0.9583 - val_loss: 0.7174
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9307 - loss: 0.7423 - val_accuracy: 0.9583 - val_loss: 0.6991
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9101 - loss: 0.7244 - val_accuracy: 0.9583 - val_loss: 0.6808
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9402 - loss: 0.6815 - val_accuracy: 0.9583 - val_loss: 0.6630
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9219 - loss: 0.6743 - val_accuracy: 0.9583 - val_loss: 0.6462
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9046 - loss: 0.6674 - val_accuracy: 0.9583 - val_loss: 0.6301
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9284 - loss: 0.6282 - val_accuracy: 0.9583 - val_loss: 0.6141
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9432 - loss: 0.5985 - val_accuracy: 0.9583 - val_loss: 0.5992
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8853 - loss: 0.6055 - val_accuracy: 0.9583 - val_loss: 0.5852
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9009 - loss: 0.5854 - val_accuracy: 0.9583 - val_loss: 0.5714
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9073 - loss: 0.5704 - val_accuracy: 0.9583 - val_loss: 0.5579
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8582 - loss: 0.5577 - val_accuracy: 0.9583 - val_loss: 0.5448
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8935 - loss: 0.5442 - val_accuracy: 0.9583 - val_loss: 0.5328
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9034 - loss: 0.5322 - val_accuracy: 0.9583 - val_loss: 0.5210
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9013 - loss: 0.5036 - val_accuracy: 0.9583 - val_loss: 0.5099
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8887 - loss: 0.4775 - val_accuracy: 0.9167 - val_loss: 0.4993
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8839 - loss: 0.4776 - val_accuracy: 0.9167 - val_loss: 0.4890
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8891 - loss: 0.4803 - val_accuracy: 0.9167 - val_loss: 0.4788
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8641 - loss: 0.5225 - val_accuracy: 0.9167 - val_loss: 0.4697
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8850 - loss: 0.4712 - val_accuracy: 0.9167 - val_loss: 0.4593
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9268 - loss: 0.4377 - val_accuracy: 0.9167 - val_loss: 0.4505
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9247 - loss: 0.4355 - val_accuracy: 0.9167 - val_loss: 0.4413
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9302 - loss: 0.3992 - val_accuracy: 0.9167 - val_loss: 0.4330
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 0.3125 - loss: 1.3767 - val_accuracy: 0.2917 - val_loss: 1.2685
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.2835 - loss: 1.3271 - val_accuracy: 0.2917 - val_loss: 1.2331
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3461 - loss: 1.2167 - val_accuracy: 0.2917 - val_loss: 1.2022
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2750 - loss: 1.2455 - val_accuracy: 0.3333 - val_loss: 1.1753
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3749 - loss: 1.1395 - val_accuracy: 0.3750 - val_loss: 1.1512
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.3500 - loss: 1.1522 - val_accuracy: 0.4167 - val_loss: 1.1271
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.4609 - loss: 1.1059 - val_accuracy: 0.5000 - val_loss: 1.1049
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5469 - loss: 1.0478 - val_accuracy: 0.5417 - val_loss: 1.0833
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4964 - loss: 1.0653 - val_accuracy: 0.5417 - val_loss: 1.0630
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5789 - loss: 1.0193 - val_accuracy: 0.5833 - val_loss: 1.0399
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5875 - loss: 1.0065 - val_accuracy: 0.6667 - val_loss: 1.0176
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7336 - loss: 0.9756 - val_accuracy: 0.7917 - val_loss: 0.9960
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7688 - loss: 0.9900 - val_accuracy: 0.7917 - val_loss: 0.9725
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8135 - loss: 0.9505 - val_accuracy: 0.8333 - val_loss: 0.9508
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7979 - loss: 0.9374 - val_accuracy: 0.8750 - val_loss: 0.9269
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7658 - loss: 0.9297 - val_accuracy: 0.8750 - val_loss: 0.9033
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8417 - loss: 0.8606 - val_accuracy: 0.8333 - val_loss: 0.8800
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8045 - loss: 0.8660 - val_accuracy: 0.8750 - val_loss: 0.8560
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7976 - loss: 0.8378 - val_accuracy: 0.8750 - val_loss: 0.8333
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8601 - loss: 0.8083 - val_accuracy: 0.8750 - val_loss: 0.8079
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8513 - loss: 0.7964 - val_accuracy: 0.8750 - val_loss: 0.7837
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8317 - loss: 0.7494 - val_accuracy: 0.8750 - val_loss: 0.7580
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8533 - loss: 0.7228 - val_accuracy: 0.8750 - val_loss: 0.7323
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8234 - loss: 0.7311 - val_accuracy: 0.8750 - val_loss: 0.7064
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8031 - loss: 0.7168 - val_accuracy: 0.8750 - val_loss: 0.6797
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7958 - loss: 0.7048 - val_accuracy: 0.8750 - val_loss: 0.6580
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8403 - loss: 0.6373 - val_accuracy: 0.8750 - val_loss: 0.6353
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8570 - loss: 0.6040 - val_accuracy: 0.8750 - val_loss: 0.6118
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8225 - loss: 0.6114 - val_accuracy: 0.8750 - val_loss: 0.5896
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8551 - loss: 0.5671 - val_accuracy: 0.8750 - val_loss: 0.5689
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8268 - loss: 0.5581 - val_accuracy: 0.8750 - val_loss: 0.5493
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8467 - loss: 0.5377 - val_accuracy: 0.8750 - val_loss: 0.5317
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8743 - loss: 0.5057 - val_accuracy: 0.8750 - val_loss: 0.5142
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8824 - loss: 0.4950 - val_accuracy: 0.8750 - val_loss: 0.4970
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9287 - loss: 0.4477 - val_accuracy: 0.9167 - val_loss: 0.4803
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9024 - loss: 0.4359 - val_accuracy: 0.9167 - val_loss: 0.4671
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9208 - loss: 0.4187 - val_accuracy: 0.9167 - val_loss: 0.4517
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9094 - loss: 0.4328 - val_accuracy: 0.9167 - val_loss: 0.4407
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8865 - loss: 0.4187 - val_accuracy: 0.9167 - val_loss: 0.4292
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8902 - loss: 0.4103 - val_accuracy: 0.9167 - val_loss: 0.4186
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8634 - loss: 0.4105 - val_accuracy: 0.9167 - val_loss: 0.4052
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9121 - loss: 0.3541 - val_accuracy: 0.9167 - val_loss: 0.3954
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9161 - loss: 0.3773 - val_accuracy: 0.9583 - val_loss: 0.3884
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9379 - loss: 0.3366 - val_accuracy: 0.9583 - val_loss: 0.3783
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9161 - loss: 0.3444 - val_accuracy: 0.9583 - val_loss: 0.3696
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9387 - loss: 0.3060 - val_accuracy: 0.9583 - val_loss: 0.3608
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9491 - loss: 0.3173 - val_accuracy: 0.9583 - val_loss: 0.3537
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9536 - loss: 0.2773 - val_accuracy: 0.9583 - val_loss: 0.3491
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9234 - loss: 0.2914 - val_accuracy: 0.9583 - val_loss: 0.3413
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9353 - loss: 0.2836 - val_accuracy: 0.9583 - val_loss: 0.3356
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step

# %% [markdown]
# ##### **Task 2: Wine Dataset - Build and Train a Neural Network**
# 1. **Objective**:
#    To build and train a neural network for classification using the Wine dataset, exploring a more complex feature space.
#
# 2. **Steps**:
#    - **Data Preprocessing**: Features are standardized, and target labels are one-hot encoded.
#    - **Neural Network Architecture**:
#      - Two hidden layers:
#        - 8 neurons in the first hidden layer.
#        - 16 neurons in the second hidden layer.
#      - ReLU activation for hidden layers.
#      - Softmax activation for the output layer (3 output units for 3 classes).
#    - **Training and Evaluation**:
#      - The model is trained for 50 epochs with a validation split of 20%.
#      - Training and validation loss/accuracy plots are generated.
#      - A confusion matrix is created for test dataset predictions.
#
# 3. **Deliverables**:
#    - Training and validation loss/accuracy plots.
#    - Confusion matrix for test dataset predictions.
#    - Evaluation of test accuracy.
#
# ---
#
# #### **Results and Observations**
# 1. **Iris Dataset**:
#    - Adding an additional hidden layer improved the test accuracy slightly due to increased model capacity.
#    - The model was simple enough to perform well on the Iris dataset even with fewer layers.
#
# 2. **Wine Dataset**:
#    - The two-layer architecture provided adequate performance for the more complex Wine dataset, which has a larger feature set and more variability.
#    - The confusion matrix highlighted the model's classification performance for the three wine classes.
#
# ---
#
# #### **Key Concepts Demonstrated**
# - **Data Preprocessing**: Standardization and one-hot encoding for preparing data.
# - **Neural Network Architecture**: Adjusting the number of hidden layers and neurons to optimize performance.
# - **Training Visualization**: Using plots to track training and validation loss/accuracy over epochs.
# - **Performance Evaluation**: Leveraging metrics like confusion matrices and test accuracy for evaluation.
#
# ---
#
# #### **Instructions for Running on Google Colab**
# 1. **Setup Environment**: Ensure necessary libraries like TensorFlow, NumPy, Scikit-learn, and Matplotlib are installed in the Colab environment.
# 2. **Run the Notebook**: Execute each code cell sequentially.
# 3. **Outputs**:
#    - Training and validation loss/accuracy plots will be displayed after training.
#    - Confusion matrices will be visualized for both tasks.
# 4. **Analyze Results**: Compare the results of the original and modified networks for the Iris dataset and evaluate the Wine dataset performance.
#
# ---
#
# #### **Conclusion**
# This project highlights the importance of:
# - Adjusting neural network architecture for different datasets.
# - Using visualization tools to understand model performance.
# - Preprocessing steps in ensuring consistent results across datasets.

# %%
# Task 2: Wine Dataset - Build and Train a Neural Network

# Import necessary libraries (reuse imports from Task 1)
from sklearn.datasets import load_wine

# Load and preprocess Wine dataset
wine = load_wine()
X_wine, y_wine = wine.data, wine.target
X_wine, y_wine = preprocess_data(X_wine, y_wine)

X_train_wine, X_test_wine, y_train_wine, y_test_wine = train_test_split(
    X_wine, y_wine, test_size=0.2, random_state=42
)

# Build and train the model for the Wine dataset
wine_model = build_model(input_shape=X_train_wine.shape[1], hidden_layers=[8, 16], output_units=3)
history_wine = wine_model.fit(
    X_train_wine, y_train_wine, validation_split=0.2, epochs=50, batch_size=16, verbose=1
)

# Visualization for Task 2
plot_training_results(history_wine, "Model (Wine Dataset)")

# Confusion Matrix for Task 2
plot_confusion_matrix(
    wine_model, X_test_wine, y_test_wine, labels=wine.target_names, dataset_name="Wine Dataset"
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.5937 - loss: 1.1056 - val_accuracy: 0.5517 - val_loss: 0.9672
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6065 - loss: 1.0346 - val_accuracy: 0.6552 - val_loss: 0.9265
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6479 - loss: 0.9397 - val_accuracy: 0.6552 - val_loss: 0.8885
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6946 - loss: 0.9196 - val_accuracy: 0.6552 - val_loss: 0.8516
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7210 - loss: 0.9046 - val_accuracy: 0.7586 - val_loss: 0.8165
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7893 - loss: 0.7662 - val_accuracy: 0.7586 - val_loss: 0.7818
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7401 - loss: 0.7877 - val_accuracy: 0.7586 - val_loss: 0.7468
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7326 - loss: 0.7605 - val_accuracy: 0.7586 - val_loss: 0.7123
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7508 - loss: 0.7328 - val_accuracy: 0.7931 - val_loss: 0.6773
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8162 - loss: 0.6647 - val_accuracy: 0.8276 - val_loss: 0.6417
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8296 - loss: 0.6439 - val_accuracy: 0.8621 - val_loss: 0.6091
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8476 - loss: 0.6154 - val_accuracy: 0.8966 - val_loss: 0.5771
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9111 - loss: 0.5477 - val_accuracy: 0.8966 - val_loss: 0.5470
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8537 - loss: 0.5839 - val_accuracy: 0.8966 - val_loss: 0.5191
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8952 - loss: 0.5182 - val_accuracy: 0.8966 - val_loss: 0.4926
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8704 - loss: 0.5152 - val_accuracy: 0.8966 - val_loss: 0.4678
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9337 - loss: 0.4262 - val_accuracy: 0.8966 - val_loss: 0.4442
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9019 - loss: 0.4210 - val_accuracy: 0.8966 - val_loss: 0.4202
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9003 - loss: 0.4337 - val_accuracy: 0.9310 - val_loss: 0.3972
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9095 - loss: 0.4191 - val_accuracy: 0.9310 - val_loss: 0.3739
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9249 - loss: 0.3910 - val_accuracy: 0.9310 - val_loss: 0.3511
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9561 - loss: 0.3487 - val_accuracy: 0.9310 - val_loss: 0.3308
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9571 - loss: 0.3374 - val_accuracy: 0.9310 - val_loss: 0.3141
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9747 - loss: 0.2583 - val_accuracy: 0.9310 - val_loss: 0.2973
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9600 - loss: 0.2754 - val_accuracy: 0.9310 - val_loss: 0.2830
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9553 - loss: 0.2629 - val_accuracy: 0.9310 - val_loss: 0.2697
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9527 - loss: 0.2656 - val_accuracy: 0.9310 - val_loss: 0.2581
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9550 - loss: 0.2496 - val_accuracy: 0.9310 - val_loss: 0.2500
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9334 - loss: 0.2915 - val_accuracy: 0.9310 - val_loss: 0.2411
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9418 - loss: 0.2525 - val_accuracy: 0.9310 - val_loss: 0.2312
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9691 - loss: 0.2005 - val_accuracy: 0.9310 - val_loss: 0.2229
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9615 - loss: 0.2015 - val_accuracy: 0.9310 - val_loss: 0.2172
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9653 - loss: 0.1968 - val_accuracy: 0.9310 - val_loss: 0.2105
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9632 - loss: 0.2187 - val_accuracy: 0.9310 - val_loss: 0.2080
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9774 - loss: 0.1814 - val_accuracy: 0.9310 - val_loss: 0.2027
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9808 - loss: 0.1527 - val_accuracy: 0.9310 - val_loss: 0.1959
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9704 - loss: 0.1878 - val_accuracy: 0.9310 - val_loss: 0.1878
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9774 - loss: 0.1451 - val_accuracy: 0.9310 - val_loss: 0.1796
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9546 - loss: 0.1931 - val_accuracy: 0.9310 - val_loss: 0.1736
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9814 - loss: 0.1385 - val_accuracy: 0.9310 - val_loss: 0.1666
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9687 - loss: 0.1648 - val_accuracy: 0.9310 - val_loss: 0.1629
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9685 - loss: 0.1474 - val_accuracy: 0.9310 - val_loss: 0.1600
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9843 - loss: 0.1314 - val_accuracy: 0.9310 - val_loss: 0.1513
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.1222 - val_accuracy: 0.9310 - val_loss: 0.1471
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9832 - loss: 0.1443 - val_accuracy: 0.9655 - val_loss: 0.1439
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9797 - loss: 0.1452 - val_accuracy: 0.9655 - val_loss: 0.1412
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9875 - loss: 0.1423 - val_accuracy: 0.9655 - val_loss: 0.1388
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9904 - loss: 0.1097 - val_accuracy: 0.9655 - val_loss: 0.1368
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9759 - loss: 0.1235 - val_accuracy: 0.9655 - val_loss: 0.1354
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9890 - loss: 0.1021 - val_accuracy: 0.9655 - val_loss: 0.1331
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
